# %%
import pandas as pd
sup_sale = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/superstore_sales.csv")

# %%
data = pd.DataFrame(sup_sale)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# ![Screenshot 2025-03-31 111555.png](data:image/png;base64,...)

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   08/11/16  11/11/16    Second Class    CG-12520
# 1       2  CA-2016-152156   08/11/16  11/11/16    Second Class    CG-12520
# 2       3  CA-2016-138688   12/06/16  16/06/16    Second Class    DV-13045
# 3       4  US-2015-108966   11/10/15  18/10/15  Standard Class    SO-20335
# 4       5  US-2015-108966   11/10/15  18/10/15  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales Price      float64
# Quantity         float64
# Discount         float64
# Profit           float64
# dtype: object

# %%
data.describe()
# Out:
#              Row ID   Postal Code   Sales Price     Quantity      Discount  \
# count  10014.000000  10014.000000  10014.000000  9996.000000  10014.000000
# mean    4997.523367  55205.131616    230.038424     3.792517      0.156240
# std     2888.981754  32066.711027    623.057359     2.231021      0.206392
# min        1.000000   1040.000000    -31.500000     1.000000      0.000000
# 25%     2494.250000  23223.000000     17.280000     2.000000      0.000000
# 50%     4997.500000  57103.000000     54.780000     3.000000      0.200000
# 75%     7500.750000  90008.000000    209.970000     5.000000      0.200000
# max     9994.000000  99301.000000  22638.480000    14.000000      0.800000
#
#              Profit
# count  10014.000000
# mean      28.708317
# std      234.154272
# min    -6599.978000
# 25%        1.731375
# 50%        8.666500
# 75%       29.364000
# max     8399.976000

# %%
data.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1240
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              54
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales Price      5829
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode        98
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales Price       0
# Quantity         18
# Discount          0
# Profit            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(17)

# %%
#### Identify any obvious data quality issues or inconsistencies.

# %% [markdown]
# Here are some data quality issues and inconsistencies are
#
# 1) Missing values are in
#
# Ship Mode column - 98 missing values.
#
# Quantity column -  18 missing values.
#
# 2) Data type issues  are in
#
# Order Date and Ship Date columns are stored as object type instead of datetime.
#
# Postal Code is stored as an int64, but it should be in string type.
#
# 3)  Duplicates columns are 17.

# %%
data.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales Price      float64
# Quantity         float64
# Discount         float64
# Profit           float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode        98
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales Price       0
# Quantity         18
# Discount          0
# Profit            0
# dtype: int64

# %%
data[data["Ship Mode"].isna()]
# Out:
#       Row ID        Order ID Order Date  Ship Date Ship Mode Customer ID  \
# 366      367  CA-2016-155516   21/10/16   21/10/16       NaN    MK-17905
# 367      368  CA-2016-155516   21/10/16   21/10/16       NaN    MK-17905
# 368      369  CA-2016-155516   21/10/16   21/10/16       NaN    MK-17905
# 369      370  CA-2016-155516   21/10/16   21/10/16       NaN    MK-17905
# 459      460  CA-2015-109638   15/12/15   22/12/15       NaN    JH-15985
# 460      461  CA-2015-109638   15/12/15   22/12/15       NaN    JH-15985
# 461      462  CA-2015-109638   15/12/15   22/12/15       NaN    JH-15985
# 462      463  CA-2016-109869   22/04/16   29/04/16       NaN    TN-21040
# 463      464  CA-2016-109869   22/04/16   29/04/16       NaN    TN-21040
# 464      465  CA-2016-109869   22/04/16   29/04/16       NaN    TN-21040
# 465      466  CA-2016-109869   22/04/16   29/04/16       NaN    TN-21040
# 466      467  CA-2016-109869   22/04/16   29/04/16       NaN    TN-21040
# ...

# %%
data[data["Quantity"].isna()]
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 13        14  CA-2016-161389   05/12/16    10/12/16  Standard Class
# 15        16  US-2015-118983   22/11/15    26/11/15  Standard Class
# 19        20  CA-2014-143336   27/08/14    2014-9-1    Second Class
# 24        25  CA-2015-106320   25/09/15    30/09/15  Standard Class
# 26        27  CA-2016-121755   16/01/16    20/01/16    Second Class
# 29        30  US-2015-150630   17/09/15    21/09/15  Standard Class
# 9058    9059  CA-2015-149097   20/10/15    24/10/15  Standard Class
# 9064    9065  US-2014-151015   14/10/14  2014-10-20  Standard Class
# 9068    9069  CA-2016-106278   02/09/16    05/09/16    Second Class
# 9069    9070  CA-2016-106278   02/09/16    05/09/16    Second Class
# 9070    9071  CA-2017-147550   04/12/17    05/12/17     First Class
# 9075    9076  US-2015-136259   05/11/15    08/11/15     First Class
# 9487    9488  US-2017-125213   11/12/17    13/12/17     First Class
# ...

# %%
data["Quantity"].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10009    False
# 10010    False
# 10011    False
# 10012    False
# 10013    False
# Name: Quantity, Length: 10014, dtype: bool

# %%
data["Postal Code"] = data["Postal Code"].astype(str)

# %%
data.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code       object
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales Price      float64
# Quantity         float64
# Discount         float64
# Profit           float64
# dtype: object

# %%
data
# Out:
#        Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0           1  CA-2016-152156   08/11/16    11/11/16    Second Class
# 1           2  CA-2016-152156   08/11/16    11/11/16    Second Class
# 2           3  CA-2016-138688   12/06/16    16/06/16    Second Class
# 3           4  US-2015-108966   11/10/15    18/10/15  Standard Class
# 4           5  US-2015-108966   11/10/15    18/10/15  Standard Class
# ...       ...             ...        ...         ...             ...
# 10009    1048  CA-2016-169103   08/03/16    13/03/16  Standard Class
# 10010    9613  CA-2016-110086   18/09/16    22/09/16  Standard Class
# 10011    9614  CA-2014-128524   11/11/14  2014-11-13     First Class
# 10012    9615  CA-2014-128524   11/11/14  2014-11-13     First Class
# 10013    9616  CA-2014-128524   11/11/14  2014-11-13     First Class
#
#       Customer ID     Customer Name    Segment        Country  \
# 0        CG-12520       Claire Gute   Consumer  United States
# ...

# %% [markdown]
# ![Screenshot 2025-03-31 131922.png](data:image/png;base64,...)

# %%
data.duplicated().sum()
# Out:
# np.int64(17)

# %%
clean_data = data.drop_duplicates()

# %%
clean_data
# Out:
#        Row ID        Order ID Order Date Ship Date       Ship Mode  \
# 0           1  CA-2016-152156   08/11/16  11/11/16    Second Class
# 1           2  CA-2016-152156   08/11/16  11/11/16    Second Class
# 2           3  CA-2016-138688   12/06/16  16/06/16    Second Class
# 3           4  US-2015-108966   11/10/15  18/10/15  Standard Class
# 4           5  US-2015-108966   11/10/15  18/10/15  Standard Class
# ...       ...             ...        ...       ...             ...
# 9992     9993  CA-2017-121258   26/02/17  03/03/17  Standard Class
# 9993     9994  CA-2017-119914   04/05/17  09/05/17    Second Class
# 9998       20  CA-2014-143336   27/08/14  2014-9-1    Second Class
# 10000    8852  CA-2015-140718   02/07/15  04/07/15     First Class
# 10005    1044  CA-2017-115651   09/07/17  12/07/17     First Class
#
#       Customer ID       Customer Name    Segment        Country  \
# 0        CG-12520         Claire Gute   Consumer  United States
# ...

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10009     True
# 10010     True
# 10011     True
# 10012     True
# 10013     True
# Length: 10014, dtype: bool

# %%
data[data.duplicated()]
# Out:
#        Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 9994     9980  US-2016-103674   06/12/16    10/12/16  Standard Class
# 9995     9981  US-2015-151435   06/09/15    09/09/15    Second Class
# 9996       18  CA-2014-167164   13/05/14   2014-5-15    Second Class
# 9997       19  CA-2014-143336   27/08/14    2014-9-1    Second Class
# 9999       21  CA-2014-143336   27/08/14    2014-9-1    Second Class
# 10001    8853  CA-2014-119977   08/10/14  2014-10-13    Second Class
# 10002    8854  US-2015-115343   22/09/15    25/09/15     First Class
# 10003    8855  US-2015-115343   22/09/15    25/09/15     First Class
# 10004    1043  CA-2016-102981   06/09/16    09/09/16    Second Class
# 10006    1045  CA-2017-115651   09/07/17    12/07/17     First Class
# 10007    1046  CA-2017-152702   12/10/17    16/10/17  Standard Class
# 10008    1047  CA-2016-169103   08/03/16    13/03/16  Standard Class
# 10009    1048  CA-2016-169103   08/03/16    13/03/16  Standard Class
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(17)

# %%
data[data.duplicated(subset = ["Order ID"])]["Order ID"].nunique()
# Out:
# 2476

# %% [markdown]
# ![Screenshot 2025-03-31 133108.png](data:image/png;base64,...)

# %%
clean_data["Order Date"] = pd.to_datetime(clean_data["Order Date"], format= "%d/%m/%y")

clean_data["Ship Date"] = pd.to_datetime(clean_data["Ship Date"])
# Out:
# <ipython-input-26-c8d85d1b7b52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["Order Date"] = pd.to_datetime(clean_data["Order Date"], format= "%d/%m/%y")
# <ipython-input-26-c8d85d1b7b52>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   clean_data["Ship Date"] = pd.to_datetime(clean_data["Ship Date"])
# <ipython-input-26-c8d85d1b7b52>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
clean_data.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code              object
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales Price             float64
# Quantity                float64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
clean_data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
clean_data["Year"] = clean_data["Order ID"].str.slice(3,7)
# Out:
# <ipython-input-29-21f35750da4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["Year"] = clean_data["Order ID"].str.slice(3,7)

# %%
clean_data["Year"]  = clean_data["Year"].astype(int)
# Out:
# <ipython-input-30-56250f6407c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["Year"]  = clean_data["Year"].astype(int)

# %%
clean_data["Year2"] = clean_data["Order Date"].dt.year
# Out:
# <ipython-input-31-20d520ff0739>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["Year2"] = clean_data["Order Date"].dt.year

# %%
incnsst = clean_data[clean_data["Year"]!=clean_data["Year2"]]

# %%
#####  Document the number of rows and distinct Order IDs affected by these operations.

# %%
incnsst.shape[0] ## no of rows with inconsistence years.
# Out:
# 40

# %%
incnsst["Order ID"].nunique()   ## disnict Order ID affected by the years.
# Out:
# 16

# %% [markdown]
# ![Screenshot 2025-03-31 154248.png](data:image/png;base64,...)

# %%
clean_data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
clean_data["cal_days"] = (clean_data["Ship Date"] - clean_data["Order Date"]).dt.days
# Out:
# <ipython-input-37-2b54d92427e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["cal_days"] = (clean_data["Ship Date"] - clean_data["Order Date"]).dt.days

# %%
clean_data["cal_days"]
# Out:
# 0          3
# 1          3
# 2          4
# 3          7
# 4          7
#         ...
# 9992       5
# 9993     124
# 9998       5
# 10000    -86
# 10005    151
# Name: cal_days, Length: 9997, dtype: int64

# %%
clean_data["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', nan, 'Same Day'],
#       dtype=object)

# %%
clean_data["Ship Mode"].isnull().sum()
# Out:
# np.int64(98)

# %%
clean_data.loc[(clean_data["cal_days"] == 0) & (clean_data["Ship Mode"].isna()), "Ship Mode"] = "Same Day"
clean_data.loc[(clean_data["cal_days"] == 7) & (clean_data["Ship Mode"].isna()), "Ship Mode"] = "Standard Class"
clean_data.loc[clean_data["Ship Mode"].isna(), "Ship Mode"] = "Other Class"

# %%
clean_data["Ship Mode"].isnull().sum()
# Out:
# np.int64(0)

# %%
clean_data["Quantity"].isnull().sum()
# Out:
# np.int64(18)

# %%
clean_data[clean_data["Quantity"].isnull()]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 13        14  CA-2016-161389 2016-12-05 2016-10-12  Standard Class
# 15        16  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 19        20  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 24        25  CA-2015-106320 2015-09-25 2015-09-30  Standard Class
# 26        27  CA-2016-121755 2016-01-16 2016-01-20    Second Class
# 29        30  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 9058    9059  CA-2015-149097 2015-10-20 2015-10-24  Standard Class
# 9064    9065  US-2014-151015 2014-10-14 2014-10-20  Standard Class
# 9068    9069  CA-2016-106278 2016-09-02 2016-05-09    Second Class
# 9069    9070  CA-2016-106278 2016-09-02 2016-05-09    Second Class
# 9070    9071  CA-2017-147550 2017-12-04 2017-05-12     First Class
# 9075    9076  US-2015-136259 2015-11-05 2015-08-11     First Class
# 9487    9488  US-2017-125213 2017-12-11 2017-12-13     First Class
# ...

# %%
clean_data["Quantity"].median()
# Out:
# 3.0

# %%
clean_data["Quantity"] = clean_data["Quantity"].fillna(clean_data["Quantity"].median())
# Out:
# <ipython-input-46-581eeffc66e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data["Quantity"] = clean_data["Quantity"].fillna(clean_data["Quantity"].median())

# %%
print("Quantity column null values are imputed by the median method")
# Out:
# Quantity column null values are imputed by the median method

# %%
clean_data["Quantity"].isnull().sum()
# Out:
# np.int64(0)

# %%
clean_data.iloc[:20]
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1        2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2        3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3        4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4        5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5        6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6        7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7        8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8        9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9       10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10      11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %%
clean_data["Quantity"].isna().sum()  ### Number of rows affected by Quantity imputation
# Out:
# np.int64(0)

# %%
clean_data[clean_data["Quantity"].isnull()]["Order ID"].nunique() ### Distinct Order ID affected by Quantity imputation
# Out:
# 0

# %% [markdown]
# ![Screenshot 2025-03-31 174912.png](data:image/png;base64,...)

# %%
clean_data
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1           2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2           3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3           4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4           5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 9992     9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993     9994  CA-2017-119914 2017-05-04 2017-09-05    Second Class
# 9998       20  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 10000    8852  CA-2015-140718 2015-07-02 2015-04-07     First Class
# 10005    1044  CA-2017-115651 2017-07-09 2017-12-07     First Class
#
#       Customer ID       Customer Name    Segment        Country  \
# 0        CG-12520         Claire Gute   Consumer  United States
# ...

# %%
clean_data['Personal Identifiable Information'] = clean_data['Customer Name'].str.split().apply(lambda x: ''.join(word[0].upper() for word in x))
# Out:
# <ipython-input-53-4a032486741e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['Personal Identifiable Information'] = clean_data['Customer Name'].str.split().apply(lambda x: ''.join(word[0].upper() for word in x))

# %%
clean_data['Personal Identifiable Information']
# Out:
# 0         CG
# 1         CG
# 2        DVH
# 3         SO
# 4         SO
#         ...
# 9992      DB
# 9993      CC
# 9998      ZD
# 10000     FA
# 10005     NS
# Name: Personal Identifiable Information, Length: 9997, dtype: object

# %%
clean_data = clean_data.drop(columns=["Customer Name"])

# %%
clean_data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Segment        Country             City       State Postal Code Region  \
# 0   Consumer  United States        Henderson    Kentucky       42420  South
# 1   Consumer  United States        Henderson    Kentucky       42420  South
# 2  Corporate  United States      Los Angeles  California       90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida       33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida       33311  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
clean_data["Postal Code"] = clean_data["Postal Code"].astype(str).str.zfill(5)

# %% [markdown]
# ![Screenshot 2025-03-31 224117.png](data:image/png;base64,...)

# %%
clean_data.dtypes
# Out:
# Row ID                                        int64
# Order ID                                     object
# Order Date                           datetime64[ns]
# Ship Date                            datetime64[ns]
# Ship Mode                                    object
# Customer ID                                  object
# Segment                                      object
# Country                                      object
# City                                         object
# State                                        object
# Postal Code                                  object
# Region                                       object
# Product ID                                   object
# Category                                     object
# Sub-Category                                 object
# Product Name                                 object
# Sales Price                                 float64
# Quantity                                    float64
# ...

# %%
clean_data["Quantity"] = clean_data["Quantity"].astype(int)
clean_data["Sales Price"] = clean_data["Sales Price"].astype(float)

# %%
clean_data.dtypes
# Out:
# Row ID                                        int64
# Order ID                                     object
# Order Date                           datetime64[ns]
# Ship Date                            datetime64[ns]
# Ship Mode                                    object
# Customer ID                                  object
# Segment                                      object
# Country                                      object
# City                                         object
# State                                        object
# Postal Code                                  object
# Region                                       object
# Product ID                                   object
# Category                                     object
# Sub-Category                                 object
# Product Name                                 object
# Sales Price                                 float64
# Quantity                                      int64
# ...

# %% [markdown]
# ![Screenshot 2025-03-31 224710.png](data:image/png;base64,...)

# %%
clean_data["State"] = clean_data["State"].str.replace("\\","")

# %%
abb = {"CA" : "California", "NJ" : "New Jersey" , "NK" : "New York", "TX" : "Texas" , "WA" : "Washington"}
clean_data["State"] = clean_data["State"].replace(abb)

# %%
clean_data[clean_data["State"]=="Washington"]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 13        14  CA-2016-161389 2016-12-05 2016-10-12  Standard Class
# 117      118  CA-2015-110457 2015-03-02 2015-06-03  Standard Class
# 156      157  CA-2015-118948 2015-05-28 2015-03-06  Standard Class
# 157      158  CA-2014-104269 2014-03-01 2014-03-06    Second Class
# 163      164  CA-2016-113817 2016-11-07 2016-11-11  Standard Class
# ...      ...             ...        ...        ...             ...
# 9761    9762  CA-2014-121762 2014-02-14 2014-02-18  Standard Class
# 9762    9763  CA-2014-121762 2014-02-14 2014-02-18  Standard Class
# 9763    9764  CA-2014-121762 2014-02-14 2014-02-18  Standard Class
# 9857    9858  CA-2015-164301 2015-03-26 2015-03-30  Standard Class
# 9944    9945  CA-2015-145415 2015-04-12 2015-04-17    Second Class
#
#      Customer ID      Segment        Country     City       State Postal Code  \
# 13      IM-15070     Consumer  United States  Seattle  Washington       98103
# ...

# %% [markdown]
# ![Screenshot 2025-03-31 231838.png](data:image/png;base64,...)

# %%
clean_data["Original Price"] = clean_data["Sales Price"]/(1-clean_data["Discount"])
clean_data["Total Sales"] = clean_data["Sales Price"]*clean_data["Quantity"]
clean_data["Total Profit"] = clean_data["Profit"]*clean_data["Quantity"]
clean_data["Discount Price"] = clean_data["Original Price"]*clean_data["Discount"]
clean_data["Total Discount"] = clean_data["Discount Price"]*clean_data["Quantity"]

# %%
clean_data
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1           2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2           3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3           4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4           5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 9992     9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993     9994  CA-2017-119914 2017-05-04 2017-09-05    Second Class
# 9998       20  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 10000    8852  CA-2015-140718 2015-07-02 2015-04-07     First Class
# 10005    1044  CA-2017-115651 2017-07-09 2017-12-07     First Class
#
#       Customer ID    Segment        Country             City           State  \
# ...

# %% [markdown]
# ![Screenshot 2025-03-31 233706.png](data:image/png;base64,...)

# %%
clean_data["Days to Ship"] = (clean_data["Ship Date"] - clean_data["Order Date"]).dt.days

# %%
clean_data["Days to Ship"].isna().sum()
# Out:
# np.int64(0)

# %%
clean_data.loc[clean_data["Days to Ship"]==0, "Shipping Urgency"]="Immediate"
clean_data.loc[(clean_data["Days to Ship"]>1)& (clean_data["Days to Ship"]<3 ) , "Shipping Urgency"]="Urgent"
clean_data.loc[clean_data["Days to Ship"]>3  , "Shipping Urgency"]="Standard"
clean_data.loc[clean_data["Shipping Urgency"].isnull()  , "Shipping Urgency"]="Other"

# %%
clean_data[ "Shipping Urgency"].unique()
# Out:
# array(['Other', 'Standard', 'Urgent', 'Immediate'], dtype=object)

# %%
clean_data = clean_data.sort_values(["Customer ID","Order Date"])

# %%
clean_data["Days Since Last Order"] = clean_data.groupby("Customer ID")["Order Date"].diff().dt.days.fillna(0)

# %%
clean_data.head()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2229    2230  CA-2014-128055 2014-03-31 2014-04-05  Standard Class
# 2230    2231  CA-2014-128055 2014-03-31 2014-04-05  Standard Class
# 7468    7469  CA-2014-138100 2014-09-15 2014-09-20  Standard Class
# 7469    7470  CA-2014-138100 2014-09-15 2014-09-20  Standard Class
# 1299    1300  CA-2015-121391 2015-10-04 2015-07-10     First Class
#
#      Customer ID   Segment        Country           City       State  \
# 2229    AA-10315  Consumer  United States  San Francisco  California
# 2230    AA-10315  Consumer  United States  San Francisco  California
# 7468    AA-10315  Consumer  United States  New York City    New York
# 7469    AA-10315  Consumer  United States  New York City    New York
# 1299    AA-10315  Consumer  United States  San Francisco  California
#
#      Postal Code Region       Product ID         Category Sub-Category  \
# 2229       94122   West  OFF-BI-10004390  Office Supplies      Binders
# ...

# %%
customer_details  = clean_data.groupby("Customer ID").agg({"Total Sales" : "sum", "Quantity" : "sum", "Discount" : "sum"})

# %%
customer_details
# Out:
#              Total Sales  Quantity  Discount
# Customer ID
# AA-10315       16073.344        30      1.00
# AA-10375        2734.830        41      1.20
# AA-10480        5493.936        36      0.20
# AA-10645       22927.855        64      1.15
# AB-10015        1984.480        13      0.40
# ...                  ...       ...       ...
# XP-21865        8676.214       100      1.30
# YC-21895       27208.926        31      0.60
# YS-21880       46478.992        58      0.60
# ZC-21910       40212.889       105      7.90
# ZD-21925        7132.888        35      1.20
#
# [793 rows x 3 columns]

# %%
customer_details = customer_details.rename(columns={"Total Sales" : "Total Sales Merge","Quantity" : "Quantity_merge", "Discount" : "Discount_merge"})

# %%
clean_data = clean_data.merge(customer_details, on = "Customer ID")

# %%
clean_data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    2230  CA-2014-128055 2014-03-31 2014-04-05  Standard Class    AA-10315
# 1    2231  CA-2014-128055 2014-03-31 2014-04-05  Standard Class    AA-10315
# 2    7469  CA-2014-138100 2014-09-15 2014-09-20  Standard Class    AA-10315
# 3    7470  CA-2014-138100 2014-09-15 2014-09-20  Standard Class    AA-10315
# 4    1300  CA-2015-121391 2015-10-04 2015-07-10     First Class    AA-10315
#
#     Segment        Country           City       State Postal Code Region  \
# 0  Consumer  United States  San Francisco  California       94122   West
# 1  Consumer  United States  San Francisco  California       94122   West
# 2  Consumer  United States  New York City    New York       10011   East
# 3  Consumer  United States  New York City    New York       10011   East
# 4  Consumer  United States  San Francisco  California       94109   West
#
#         Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ![Screenshot 2025-04-01 210027.png](data:image/png;base64,...)

# %%
def remove_outliers(dataframe, column):
  Q1 = dataframe[column].quantile(0.25)
  Q3 = dataframe[column].quantile(0.75)
  IQR = Q3-Q1
  lower_bound = Q1 - 3 * IQR
  upper_bound = Q3 + 3 * IQR

  return dataframe[(dataframe[column] >= lower_bound) & (dataframe[column] <= upper_bound)]

# %%
remove_outliers(clean_data, "Sales Price")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       2230  CA-2014-128055 2014-03-31 2014-04-05  Standard Class
# 1       2231  CA-2014-128055 2014-03-31 2014-04-05  Standard Class
# 2       7469  CA-2014-138100 2014-09-15 2014-09-20  Standard Class
# 3       7470  CA-2014-138100 2014-09-15 2014-09-20  Standard Class
# 4       1300  CA-2015-121391 2015-10-04 2015-07-10     First Class
# ...      ...             ...        ...        ...             ...
# 9991    5898  CA-2016-167682 2016-04-03 2016-09-04  Standard Class
# 9992    5899  CA-2016-167682 2016-04-03 2016-09-04  Standard Class
# 9993    3041  US-2016-147991 2016-05-05 2016-09-05  Standard Class
# 9995    3816  CA-2016-152471 2016-07-08 2016-08-07        Same Day
# 9996    8342  CA-2017-141481 2017-06-11 2017-06-14     First Class
#
#      Customer ID   Segment        Country           City       State  \
# 0       AA-10315  Consumer  United States  San Francisco  California
# ...

# %% [markdown]
# ![Screenshot 2025-04-02 013200.png](data:image/png;base64,...)

# %%
customer_total = clean_data.groupby("Customer ID").agg({"Sales Price" : "sum", "Profit" : "sum"}).reset_index()

# %%
customer_total
# Out:
#     Customer ID  Sales Price     Profit
# 0      AA-10315     5563.560  -362.8825
# 1      AA-10375     1056.390   277.3824
# 2      AA-10480     1790.512   435.8274
# 3      AA-10645     5086.935   857.8033
# 4      AB-10015      886.156   129.3465
# ..          ...          ...        ...
# 788    XP-21865     2374.658   621.2300
# 789    YC-21895     5454.350  1305.6290
# 790    YS-21880     6720.444  1778.2923
# 791    ZC-21910     8025.707 -1032.1490
# 792    ZD-21925     1707.424   265.1417
#
# [793 rows x 3 columns]

# %%
customer_total["Sales_quintile"] = pd.qcut(customer_total["Sales Price"], 5, labels = ["Q1", "Q2", "Q3", "Q4", "Q5"])

# %%
customer_total
# Out:
#     Customer ID  Sales Price     Profit Sales_quintile
# 0      AA-10315     5563.560  -362.8825             Q5
# 1      AA-10375     1056.390   277.3824             Q2
# 2      AA-10480     1790.512   435.8274             Q3
# 3      AA-10645     5086.935   857.8033             Q5
# 4      AB-10015      886.156   129.3465             Q1
# ..          ...          ...        ...            ...
# 788    XP-21865     2374.658   621.2300             Q3
# 789    YC-21895     5454.350  1305.6290             Q5
# 790    YS-21880     6720.444  1778.2923             Q5
# 791    ZC-21910     8025.707 -1032.1490             Q5
# 792    ZD-21925     1707.424   265.1417             Q2
#
# [793 rows x 4 columns]

# %%
customer_total["Profit_quintile"] = pd.qcut(customer_total["Profit"], 5 , labels=["Q1", "Q2" , "Q3" , "Q4" , "Q5"] )

# %%
customer_total
# Out:
#     Customer ID  Sales Price     Profit Sales_quintile Profit_quintile
# 0      AA-10315     5563.560  -362.8825             Q5              Q1
# 1      AA-10375     1056.390   277.3824             Q2              Q3
# 2      AA-10480     1790.512   435.8274             Q3              Q4
# 3      AA-10645     5086.935   857.8033             Q5              Q5
# 4      AB-10015      886.156   129.3465             Q1              Q2
# ..          ...          ...        ...            ...             ...
# 788    XP-21865     2374.658   621.2300             Q3              Q4
# 789    YC-21895     5454.350  1305.6290             Q5              Q5
# 790    YS-21880     6720.444  1778.2923             Q5              Q5
# 791    ZC-21910     8025.707 -1032.1490             Q5              Q1
# 792    ZD-21925     1707.424   265.1417             Q2              Q3
#
# [793 rows x 5 columns]

# %%
customer_total = customer_total.rename(columns={"Sales_quintile": "Sales_quintile_merged", "Profit_quintile": "Profit_quintile_merged"})

# %%
clean_data = clean_data.merge(customer_total[["Customer ID" , "Sales_quintile_merged" , "Profit_quintile_merged"]], on = "Customer ID")

# %%
clean_data
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       2230  CA-2014-128055 2014-03-31 2014-04-05  Standard Class
# 1       2231  CA-2014-128055 2014-03-31 2014-04-05  Standard Class
# 2       7469  CA-2014-138100 2014-09-15 2014-09-20  Standard Class
# 3       7470  CA-2014-138100 2014-09-15 2014-09-20  Standard Class
# 4       1300  CA-2015-121391 2015-10-04 2015-07-10     First Class
# ...      ...             ...        ...        ...             ...
# 9992    5899  CA-2016-167682 2016-04-03 2016-09-04  Standard Class
# 9993    3041  US-2016-147991 2016-05-05 2016-09-05  Standard Class
# 9994    3815  CA-2016-152471 2016-07-08 2016-08-07        Same Day
# 9995    3816  CA-2016-152471 2016-07-08 2016-08-07        Same Day
# 9996    8342  CA-2017-141481 2017-06-11 2017-06-14     First Class
#
#      Customer ID   Segment        Country           City       State  \
# 0       AA-10315  Consumer  United States  San Francisco  California
# ...

# %%
cross_grid = pd.crosstab(clean_data["Sales_quintile_merged"], clean_data["Profit_quintile_merged"])

# %%
cross_grid
# Out:
# Profit_quintile_merged   Q1   Q2   Q3   Q4    Q5
# Sales_quintile_merged
# Q1                      219  617  230    7     0
# Q2                      390  265  670  286     0
# Q3                      375  234  468  815   161
# Q4                      462  253  335  769   544
# Q5                      348  114  217  339  1879

# %% [markdown]
# ![Screenshot 2025-04-02 022646.png](data:image/png;base64,...)

# %%
Top_profit_products = clean_data.groupby("Product Name").agg({"Sales Price" : "sum","Profit" : "sum"}).reset_index()

# %%
Top_profit_products.sort_values(by = "Profit", ascending = False)
# Out:
#                                           Product Name  Sales Price  \
# 404              Canon imageCLASS 2200 Advanced Copier    61599.824
# 650  Fellowes PB500 Electric Punch Plastic Comb Bin...    27453.384
# 805               Hewlett Packard LaserJet 3310 Copier    18839.686
# 400                 Canon PC1060 Personal Laser Copier    11619.834
# 787  HP Designjet T520 Inkjet Large Format Printer ...    18374.895
# ..                                                 ...          ...
# 376  Bush Advantage Collection Racetrack Conference...     9544.725
# 425  Chromcraft Bull-Nose Wood Oval Conference Tabl...     9917.640
# 476          Cubify CubeX 3D Printer Triple Head Print     7999.980
# 985          Lexmark MX611dhe Monochrome Laser Printer    16829.901
# 475          Cubify CubeX 3D Printer Double Head Print    11099.963
#
#          Profit
# 404  25199.9280
# 650   7753.0390
# 805   6983.8836
# 400   4570.9347
# 787   4094.9766
# ..          ...
# 376  -1934.3976
# ...

# %%
Top_10_profit_products = Top_profit_products.sort_values(by = "Profit", ascending = False).head(10)

# %%
Top_10_Loss_Making_products = Top_profit_products.sort_values(by = "Profit", ascending = False).tail(10)

# %%
Top_10_Loss_Making_products.tail(3)
# Out:
#                                   Product Name  Sales Price     Profit
# 476  Cubify CubeX 3D Printer Triple Head Print     7999.980 -3839.9904
# 985  Lexmark MX611dhe Monochrome Laser Printer    16829.901 -4589.9730
# 475  Cubify CubeX 3D Printer Double Head Print    11099.963 -8879.9704

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20, 10))
sns.barplot(data=Top_10_profit_products, x = "Product Name", y= "Profit")
plt.title("Top 10 Most Profitable Products")
plt.xlabel("Product Name")
plt.xticks(rotation=90)
plt.ylabel("Total Profit")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data=Top_10_Loss_Making_products, x = "Product Name", y= "Profit")
plt.title("Top 10 Most Profitable Products")
plt.xlabel("Product Name")
plt.xticks(rotation=90)
plt.ylabel("Total Loss")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=Top_profit_products , x="Sales Price", y="Profit", scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title("Sales vs. Profit Correlation")
plt.xlabel("Total Sales Price")
plt.ylabel("Total Profit")
plt.show()

# %%
sns.jointplot(data=Top_profit_products , x="Sales Price", y="Profit", kind='scatter', alpha=0.5)
plt.suptitle("Joint Distribution of Sales and Profit")
plt.xlabel("Total Sales Price")
plt.ylabel("Total Profit")
plt.show()

# %% [markdown]
# ![Screenshot 2025-04-02 040100.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cross_grid, annot= True, cmap='coolwarm', fmt='d' )
plt.title("Customer Sales Quintile vs. Customer Profit Quintile")
plt.show()

# %%
clean_data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    2230  CA-2014-128055 2014-03-31 2014-04-05  Standard Class    AA-10315
# 1    2231  CA-2014-128055 2014-03-31 2014-04-05  Standard Class    AA-10315
# 2    7469  CA-2014-138100 2014-09-15 2014-09-20  Standard Class    AA-10315
# 3    7470  CA-2014-138100 2014-09-15 2014-09-20  Standard Class    AA-10315
# 4    1300  CA-2015-121391 2015-10-04 2015-07-10     First Class    AA-10315
#
#     Segment        Country           City       State Postal Code Region  \
# 0  Consumer  United States  San Francisco  California       94122   West
# 1  Consumer  United States  San Francisco  California       94122   West
# 2  Consumer  United States  New York City    New York       10011   East
# 3  Consumer  United States  New York City    New York       10011   East
# 4  Consumer  United States  San Francisco  California       94109   West
#
#         Product ID         Category Sub-Category  \
# ...

# %%
category_segment_pivot = clean_data.pivot_table(values=["Sales Price" , "Profit"], index='Category', columns='Segment', aggfunc='sum')

# %%
category_segment_pivot
# Out:
#                      Profit                         Sales Price               \
# Segment            Consumer   Corporate Home Office    Consumer    Corporate
# Category
# Furniture         6991.0786   7584.8158   3875.3784  391049.312  229019.7858
# Office Supplies  56330.3210  40233.5909  25933.1596  363852.656  230658.2300
# Technology       70813.8206  44166.9980  30490.1405  406613.377  246450.1190
#
#
# Segment          Home Office
# Category
# Furniture        121930.6975
# Office Supplies  124418.4340
# Technology       183304.0170

# %%
category_segment_pivot = category_segment_pivot.sort_values(by=[("Profit", "Consumer")], ascending=False)

# %%
category_segment_pivot
# Out:
#                      Profit                         Sales Price               \
# Segment            Consumer   Corporate Home Office    Consumer    Corporate
# Category
# Technology       70813.8206  44166.9980  30490.1405  406613.377  246450.1190
# Office Supplies  56330.3210  40233.5909  25933.1596  363852.656  230658.2300
# Furniture         6991.0786   7584.8158   3875.3784  391049.312  229019.7858
#
#
# Segment          Home Office
# Category
# Technology       183304.0170
# Office Supplies  124418.4340
# Furniture        121930.6975

# %%
category_segment_pivot2 = clean_data.pivot_table(values=["Total Sales" , "Total Profit"], index='Category', columns='Segment', aggfunc='sum')
category_segment_pivot2 = category_segment_pivot2.sort_values(by=[("Total Profit", "Consumer")], ascending=False)

# %%
category_segment_pivot2
# Out:
#                 Total Profit                             Total Sales  \
# Segment             Consumer    Corporate  Home Office      Consumer
# Category
# Technology       342860.3438  227239.0808  141533.0465  1.961866e+06
# Office Supplies  281887.2648  202390.8643  124996.2840  1.803054e+06
# Furniture         43925.5388   39847.2854   25818.3942  2.054328e+06
#
#
# Segment             Corporate  Home Office
# Category
# Technology       1.212598e+06  906437.7170
# Office Supplies  1.152998e+06  591731.1800
# Furniture        1.150449e+06  654438.1015

# %% [markdown]
# ![Screenshot 2025-04-02 090402.png](data:image/png;base64,...)

# %%
shipping_counts = clean_data["Shipping Urgency"].value_counts()

# %%
shipping_counts
# Out:
# Shipping Urgency
# Standard     5982
# Other        2752
# Urgent        937
# Immediate     326
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(shipping_counts, labels=shipping_counts.index,  autopct='%1.1f%%')
plt.title("Distribution of Shipping Urgency")
plt.show()

# %%
Ship_vs_Profit = clean_data[["Days to Ship","Profit"]]

# %%
Ship_vs_Profit
# Out:
#       Days to Ship    Profit
# 0                5  252.5880
# 1                5   14.8344
# 2                5    7.0218
# 3                5    6.2608
# 4              -86    7.0096
# ...            ...       ...
# 9992           154  124.7808
# 9993           123    3.3440
# 9994            30   51.4975
# 9995            30    4.9950
# 9996             3   16.5888
#
# [9997 rows x 2 columns]

# %%
plt.figure(figsize=(20,8))
sns.violinplot(data=Ship_vs_Profit, x="Days to Ship",y="Profit",inner='quartile',cut=0)
plt.title('Profit Distribution by Days to Ship')
plt.xlabel("Days to Ship")
plt.ylabel("Profit")
plt.xticks(rotation =90)
plt.show()

# %%
Shipmode_vs_Profit = clean_data.groupby("Ship Mode").agg({"Total Profit" : "sum"})

# %%
Shipmode_vs_Profit
# Out:
#                 Total Profit
# Ship Mode
# First Class      229828.1860
# Other Class       -6865.9973
# Same Day          89258.3685
# Second Class     265975.1840
# Standard Class   852302.3614

# %%
Shipmode_vs_Profit.plot(kind = "bar" , title = "Profitability of different Shipping Modes ")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(data = Shipmode_vs_Profit, x = "Ship Mode" , y = "Total Profit")
plt.title("Profitability of different Shipping Modes")
plt.xlabel("Shipping Mode")
plt.ylabel("Total Profit")
plt.show()

# %%
data2 = clean_data[["Region", "Order ID" , "Ship Mode" , "Total Profit" , "Total Sales"]]

# %%
data2
# Out:
#        Region        Order ID       Ship Mode  Total Profit  Total Sales
# 0        West  CA-2014-128055  Standard Class      505.1760     1347.136
# 1        West  CA-2014-128055  Standard Class       29.6688      105.960
# 2        East  CA-2014-138100  Standard Class       21.0654       44.820
# 3        East  CA-2014-138100  Standard Class       12.5216       29.120
# 4        West  CA-2015-121391     First Class       14.0192       53.920
# ...       ...             ...             ...           ...          ...
# 9992  Central  CA-2016-167682  Standard Class      499.1232     1039.840
# 9993    South  US-2016-147991  Standard Class       16.7200       83.600
# 9994    South  CA-2016-152471        Same Day      257.4875     4119.800
# 9995    South  CA-2016-152471        Same Day        9.9900       31.968
# 9996     West  CA-2017-141481     First Class       49.7664      184.320
#
# [9997 rows x 5 columns]

# %%
pivot_table2 = data2.pivot_table(index = "Region", columns = "Ship Mode", values = ["Order ID" , "Total Sales" , "Total Profit"], aggfunc = {"Order ID" : "count", "Total Sales" : "sum" , "Total Profit" : "sum"})

# %%
pivot_table2
# Out:
#              Order ID                                                   \
# Ship Mode First Class Other Class Same Day Second Class Standard Class
# Region
# Central         300.0         5.0    116.0        465.0         1438.0
# East            490.0        18.0    146.0        530.0         1664.0
# South           235.0         2.0     81.0        329.0          974.0
# West            515.0         NaN    185.0        622.0         1882.0
#
#           Total Profit                                                      \
# Ship Mode  First Class Other Class    Same Day Second Class Standard Class
# Region
# Central      5105.0401    160.8732   7999.1823   47510.6009    158843.6015
# East        92341.4555   8303.7891  34334.9484   50031.2048    265534.8266
# South       32215.6732 -15330.6596  10054.7236   58959.1303    141552.9490
# West       100166.0172         NaN  36869.5142  109474.2480    286370.9843
#
#            Total Sales
# ...

# %%
print("Insights are  Standard Class is more preffered across different regions." )
# Out:
# Insights are  Standard Class is more preffered across different regions.

# %% [markdown]
# ![Screenshot 2025-04-02 114853.png](data:image/png;base64,...)

# %%
By_Region = clean_data.groupby("Region").agg({"Sales Price" : "sum" , "Profit" : "sum"}).reset_index()

# %%
By_Region
# Out:
#     Region  Sales Price       Profit
# 0  Central  501194.5708   39709.3460
# 1     East  678718.2400   91522.7800
# 2    South  391712.5130   46752.7175
# 3     West  725671.3045  108434.4599

# %%
By_Region.plot(x="Region", y=["Sales Price", "Profit"], kind="bar", figsize=(10, 5))
plt.show()

# %%
clean_data.groupby("State").agg({"Profit" : "sum"})
# Out:
#                           Profit
# State
# Alabama                5786.8253
# Arizona               -3427.9246
# Arkansas               4008.6871
# CA                     3879.2302
# California            72518.1679
# Colorado              -6527.8579
# Connecticut            3511.4918
# Delaware               9977.3748
# District of Columbia   1059.5893
# Florida               -3399.3017
# Georgia               16250.0433
# Idaho                   826.7231
# Illinois             -12604.9035
# Indiana               18382.9363
# Iowa                   1183.8119
# Kansas                  836.4435
# Kentucky              11199.6966
# Louisiana              2196.1023
# Maine                   454.4862
# Maryland               7031.1788
# Massachusetts          6785.5016
# Michigan              24463.1876
# Minnesota             10823.1874
# Mississippi            3172.9762
# Missouri               6436.2105
# Montana                1833.3285
# NY                     1181.5284
# ...

# %%
state_wise_profit = clean_data.pivot_table(index = "State" , values = "Profit", aggfunc = "sum").reset_index().sort_values(by ="Profit", ascending = False)

# %%
state_wise_profit
# Out:
#                    State      Profit
# 32              New York  72857.0202
# 4             California  72518.1679
# 47            Washington  33402.6517
# 21              Michigan  24463.1876
# 46              Virginia  18597.9504
# 13               Indiana  18382.9363
# 10               Georgia  16250.0433
# 16              Kentucky  11199.6966
# 22             Minnesota  10823.1874
# 7               Delaware   9977.3748
# 30            New Jersey   9772.9138
# 49             Wisconsin   8401.8004
# 39          Rhode Island   7285.6293
# 19              Maryland   7031.1788
# 20         Massachusetts   6785.5016
# 24              Missouri   6436.2105
# 0                Alabama   5786.8253
# 36              Oklahoma   4853.9560
# 2               Arkansas   4008.6871
# 3                    CA    3879.2302
# 6            Connecticut   3511.4918
# 28                Nevada   3316.7659
# 23           Mississippi   3172.9762
# 44                  Utah   2546.5335
# ...

# %%
Top_swp = state_wise_profit.head(5)
Bottom_swp = state_wise_profit.tail(5)

# %%
Top_swp
# Out:
#          State      Profit
# 32    New York  72857.0202
# 4   California  72518.1679
# 47  Washington  33402.6517
# 21    Michigan  24463.1876
# 46    Virginia  18597.9504

# %%
Bottom_swp
# Out:
#              State      Profit
# 33  North Carolina  -7487.6250
# 12        Illinois -12604.9035
# 38    Pennsylvania -15559.9603
# 35            Ohio -16971.3766
# 43           Texas -25729.3563

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
clean_data["state_encoded"]= le.fit_transform(clean_data["State"])

# %%
clean_data["state_encoded"]
# Out:
# 0        4
# 1        4
# 2       32
# 3       32
# 4        4
#         ..
# 9992    13
# 9993    42
# 9994     9
# 9995     9
# 9996     4
# Name: state_encoded, Length: 9997, dtype: int64

# %%
corr = clean_data[["state_encoded" , "Profit"]].corr()

# %%
corr
# Out:
#                state_encoded    Profit
# state_encoded       1.000000 -0.025734
# Profit             -0.025734  1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation between State and Profit")
plt.show()

# %%
# If the correlation is positive, some states strongly contribute to profit.

# If the correlation is negative, some states tend to generate losses.

# If correlation is close to 0, then state has little direct influence on profit, and other factors like customer demographics, shipping, or discount strategies may play a bigger role.

# %% [markdown]
# ![Screenshot 2025-04-02 172957.png](data:image/png;base64,...)

# %%
clean_data.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    2230  CA-2014-128055 2014-03-31 2014-04-05  Standard Class    AA-10315
# 1    2231  CA-2014-128055 2014-03-31 2014-04-05  Standard Class    AA-10315
#
#     Segment        Country           City       State Postal Code Region  \
# 0  Consumer  United States  San Francisco  California       94122   West
# 1  Consumer  United States  San Francisco  California       94122   West
#
#         Product ID         Category Sub-Category  \
# 0  OFF-BI-10004390  Office Supplies      Binders
# 1  OFF-AP-10002765  Office Supplies   Appliances
#
#                                         Product Name  Sales Price  Quantity  \
# 0            GBC DocuBind 200 Manual Binding Machine      673.568         2
# 1  Fellowes Advanced Computer Series Surge Protec...       52.980         2
#
#    Discount    Profit  Year  Year2  cal_days  \
# 0       0.2  252.5880  2014   2014         5
# ...

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=clean_data, x="Discount", y="Profit")
plt.title("Impact of Discounts on Profitability")
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.grid(True)
plt.show()

# %%
clean_data[["Category", "Original Price" , "Discount Price"]].head(3)
# Out:
#           Category  Original Price  Discount Price
# 0  Office Supplies          841.96         168.392
# 1  Office Supplies           52.98           0.000
# 2  Office Supplies           14.94           0.000

# %%
cat_opdp = clean_data.groupby("Category").agg({"Original Price" : "mean" , "Discount Price" : "mean"}).reset_index()
cat_opdp
# Out:
#           Category  Original Price  Discount Price
# 0        Furniture      437.170858       87.335971
# 1  Office Supplies      148.974011       29.709028
# 2       Technology      562.055720      109.475897

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=cat_opdp, x="Category", y="Original Price")
sns.lineplot(data=cat_opdp, x="Category", y="Discount Price")
plt.title("Original Price vs. Discounted Price by Category")
plt.xlabel("Category")
plt.ylabel("Price")
plt.grid()
plt.show()

# %%
cat_opdp2 = clean_data.groupby("Sub-Category").agg({"Original Price" : "mean" , "Discount Price" : "mean"}).reset_index()
cat_opdp2
# Out:
#    Sub-Category  Original Price  Discount Price
# 0   Accessories      231.784284       15.809680
# 1    Appliances      272.494807       41.739097
# 2           Art       36.867980        2.852984
# 3       Binders      217.698267       84.161659
# 4     Bookcases      649.809430      145.949797
# 5        Chairs      638.282334      105.949914
# 6       Copiers     2571.289118      372.347500
# 7     Envelopes       70.645236        5.777512
# 8     Fasteners       15.320922        1.384147
# 9   Furnishings      112.408443       16.582775
# 10       Labels       36.359890        2.229912
# 11     Machines     2505.091478      859.538165
# 12        Paper       61.851058        4.615599
# 13       Phones      445.070753       74.036445
# 14      Storage      284.091099       19.500546
# 15     Supplies      265.537474       19.887274
# 16       Tables      870.494545      221.699774

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=cat_opdp2, x="Sub-Category", y="Original Price")
sns.lineplot(data=cat_opdp2, x="Sub-Category", y="Discount Price")
plt.title("Original Price vs. Discounted Price by Category")
plt.xlabel("Sub-Category")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ![Screenshot 2025-04-08 033522.png](data:image/png;base64,...)

# %%
clean_data.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    2230  CA-2014-128055 2014-03-31 2014-04-05  Standard Class    AA-10315
# 1    2231  CA-2014-128055 2014-03-31 2014-04-05  Standard Class    AA-10315
# 2    7469  CA-2014-138100 2014-09-15 2014-09-20  Standard Class    AA-10315
#
#     Segment        Country           City       State Postal Code Region  \
# 0  Consumer  United States  San Francisco  California       94122   West
# 1  Consumer  United States  San Francisco  California       94122   West
# 2  Consumer  United States  New York City    New York       10011   East
#
#         Product ID         Category Sub-Category  \
# 0  OFF-BI-10004390  Office Supplies      Binders
# 1  OFF-AP-10002765  Office Supplies   Appliances
# 2  OFF-PA-10000349  Office Supplies        Paper
#
#                                         Product Name  Sales Price  Quantity  \
# 0            GBC DocuBind 200 Manual Binding Machine      673.568         2
# ...

# %%
clean_data["Year_month"] = clean_data["Order Date"].dt.to_period("M").astype(str)
clean_data["Year_month"]
# Out:
# 0       2014-03
# 1       2014-03
# 2       2014-09
# 3       2014-09
# 4       2015-10
#          ...
# 9992    2016-04
# 9993    2016-05
# 9994    2016-07
# 9995    2016-07
# 9996    2017-06
# Name: Year_month, Length: 9997, dtype: object

# %%
sptm = clean_data.groupby("Year_month").agg({"Sales Price" : "sum", "Profit" : "sum"}).reset_index()
sptm.head()
# Out:
#   Year_month  Sales Price     Profit
# 0    1999-04     2572.500   625.8474
# 1    2013-05      740.730   219.0102
# 2    2014-01    13996.395  2438.5405
# 3    2014-02     4519.892   862.3084
# 4    2014-03    55691.009   498.7299

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x= "Year_month", y= "Sales Price", data= sptm)
sns.lineplot(x= "Year_month", y= "Profit", data = sptm)
plt.title(" Sales and Profit Trends Over Time")
plt.xlabel("Year-month")
plt.ylabel("Sales and Profit")
plt.xticks(rotation =45)
plt.grid()
plt.show()

# %%
clean_data["month"] = clean_data["Order Date"].dt.month_name()
clean_data["month"]
# Out:
# 0           March
# 1           March
# 2       September
# 3       September
# 4         October
#           ...
# 9992        April
# 9993          May
# 9994         July
# 9995         July
# 9996         June
# Name: month, Length: 9997, dtype: object

# %%
orders = clean_data["month"].value_counts().reset_index()
orders
# Out:
#         month  count
# 0    November   1471
# 1    December   1408
# 2   September   1383
# 3     October    819
# 4         May    735
# 5        June    717
# 6        July    712
# 7      August    707
# 8       March    696
# 9       April    668
# 10    January    381
# 11   February    300

# %%
plt.figure(figsize=(16,8))
sns.barplot(x = "month", y= "count", data= orders)
plt.xlabel("Month")
plt.ylabel("Number of Orders")
plt.title("Monthly Orders")
plt.show()

# %%
clean_data[["Order Date", "Sales Price" , "Profit"]]
# Out:
#      Order Date  Sales Price    Profit
# 0    2014-03-31      673.568  252.5880
# 1    2014-03-31       52.980   14.8344
# 2    2014-09-15       14.940    7.0218
# 3    2014-09-15       14.560    6.2608
# 4    2015-10-04       26.960    7.0096
# ...         ...          ...       ...
# 9992 2016-04-03      259.960  124.7808
# 9993 2016-05-05       16.720    3.3440
# 9994 2016-07-08      823.960   51.4975
# 9995 2016-07-08       15.984    4.9950
# 9996 2017-06-11       61.440   16.5888
#
# [9997 rows x 3 columns]

# %%
clean_data["year"] = clean_data["Order Date"].dt.year
clean_data["year"].unique()
# Out:
# array([2014, 2015, 2016, 2017, 1999, 2029, 2013, 2019], dtype=int32)

# %%
clean_data.groupby("year").agg({"Sales Price" : "sum", "Profit" : "sum"}).reset_index()
# Out:
#    year  Sales Price      Profit
# 0  1999    2572.5000    625.8474
# 1  2013     740.7300    219.0102
# 2  2014  482134.5631  49317.9563
# 3  2015  467915.8420  60974.8656
# 4  2016  610372.3140  81849.0935
# 5  2017  732463.3892  93367.2640
# 6  2019    1049.9700     43.2636
# 7  2029      47.3200     22.0028

# %%
samp = clean_data.groupby("year").agg({"Sales Price" : "sum", "Profit" : "sum"}).reset_index()

# %%
clean_data["Order Date"] = clean_data["Order Date"].astype(str).str.replace("2029", "2019")
clean_data["Order Date"] = pd.to_datetime(clean_data["Order Date"])

# %%
clean_data["year"] = clean_data["Order Date"].dt.year
clean_data["year"].unique()
# Out:
# array([2014, 2015, 2016, 2017, 1999, 2019, 2013], dtype=int32)

# %%
clean_data.groupby("year").agg({"Sales Price" : "sum", "Profit" : "sum"}).reset_index()
# Out:
#    year  Sales Price      Profit
# 0  1999    2572.5000    625.8474
# 1  2013     740.7300    219.0102
# 2  2014  482134.5631  49317.9563
# 3  2015  467915.8420  60974.8656
# 4  2016  610372.3140  81849.0935
# 5  2017  732463.3892  93367.2640
# 6  2019    1097.2900     65.2664

# %%
clean_data.groupby("Year_month").agg({"Sales Price" : "sum", "Profit" : "sum"}).reset_index()
# Out:
#    Year_month  Sales Price      Profit
# 0     1999-04    2572.5000    625.8474
# 1     2013-05     740.7300    219.0102
# 2     2014-01   13996.3950   2438.5405
# 3     2014-02    4519.8920    862.3084
# 4     2014-03   55691.0090    498.7299
# 5     2014-04   28295.3450   3488.8352
# 6     2014-05   23405.7770   2665.9140
# 7     2014-06   34595.1276   4976.5244
# 8     2014-07   33946.3930   -841.4826
# 9     2014-08   28122.9485   5334.1160
# 10    2014-09   80610.6348   8274.1802
# 11    2014-10   31826.6740   3387.8571
# 12    2014-11   78628.7167   9292.1269
# 13    2014-12   68495.6505   8940.3063
# 14    2015-01   18174.0756  -3281.0070
# 15    2015-02   11951.4110   2813.8508
# 16    2015-03   38726.2520   9732.0978
# 17    2015-04   31622.7085   3561.6488
# 18    2015-05   29486.6665   4499.6516
# 19    2015-06   24591.5620   3240.6833
# 20    2015-07   30211.4830   3580.2570
# 21    2015-08   36898.3322   5355.8084
# 22    2015-09   64595.9180   8209.1627
# ...

# %%
clean_data["Order Date"] = clean_data["Order Date"].astype(str).str.replace("1999", "2013")
clean_data["Order Date"] = pd.to_datetime(clean_data["Order Date"])

# %%
clean_data["year"] = clean_data["Order Date"].dt.year
clean_data["year"].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2013, 2019], dtype=int32)

# %%
yearly_data = clean_data.groupby("year").agg({"Sales Price" : "sum", "Profit" : "sum"})
yearly_data
# Out:
#       Sales Price      Profit
# year
# 2013    3313.2300    844.8576
# 2014  482134.5631  49317.9563
# 2015  467915.8420  60974.8656
# 2016  610372.3140  81849.0935
# 2017  732463.3892  93367.2640
# 2019    1097.2900     65.2664

# %%
yoy = yearly_data.pct_change()*100
yoy
# Out:
#        Sales Price       Profit
# year
# 2013           NaN          NaN
# 2014  14451.798792  5737.428260
# 2015     -2.949119    23.636238
# 2016     30.444892    34.234152
# 2017     20.002722    14.072447
# 2019    -99.850192   -99.930097

# %%
yoy_melted = pd.melt(yoy.reset_index(), id_vars=['year'], value_vars=['Sales Price', 'Profit'], var_name='Metric', value_name='Growth Rate')

plt.figure(figsize=(10, 6))
sns.barplot(x="year", y="Growth Rate", hue="Metric", data=yoy_melted)
plt.xlabel("Year")
plt.ylabel("Growth Rate")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="year", y="Sales Price", data = yoy)
sns.barplot(x="year", y="Profit", data = yoy)
plt.title("Year Over Year Sales and Profit Growth")
plt.xlabel("Year")
plt.ylabel("Growth Rate")
plt.show()
